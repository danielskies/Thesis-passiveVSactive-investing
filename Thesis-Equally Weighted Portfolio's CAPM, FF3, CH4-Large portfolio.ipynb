# %%
# !pip install financedatabase
# !pip install yfinance
# !pip install --upgrade financedatabase
# Out:
# Requirement already satisfied: financedatabase in /Users/daniel/anaconda3/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: pandas in /Users/daniel/anaconda3/lib/python3.10/site-packages (from financedatabase) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from pandas->financedatabase) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from pandas->financedatabase) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from pandas->financedatabase) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->financedatabase) (1.16.0)
# Requirement already satisfied: yfinance in /Users/daniel/anaconda3/lib/python3.10/site-packages (0.2.18)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: pandas>=1.3.0 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (2022.7)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: lxml>=4.9.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: html5lib>=1.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (1.1)
# Requirement already satisfied: requests>=2.26 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: cryptography>=3.3.2 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (39.0.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Requirement already satisfied: soupsieve>1.2 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: cffi>=1.12 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /Users/daniel/anaconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from requests>=2.26->yfinance) (2022.12.7)
# Requirement already satisfied: pycparser in /Users/daniel/anaconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)
# Requirement already satisfied: financedatabase in /Users/daniel/anaconda3/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: pandas in /Users/daniel/anaconda3/lib/python3.10/site-packages (from financedatabase) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from pandas->financedatabase) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from pandas->financedatabase) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from pandas->financedatabase) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/daniel/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas->financedatabase) (1.16.0)

# %%
import yfinance as yf
Stocks = ["FRDAX", "LMMRX", "LMPIX", "RTMTX", "MRGAX", "NSBFX",
"ITHIX", "AFYDX", "FDETX","RUSTX", "SCRLX", "AFNAX", 
"GATCX", "AEYCX", "OMSOX", "TFFCX", "GSUSX", "EVSHX",
"MCSSX","RTDYX","DRDCX","GSRLX","STRSX","MLVAX","PLJMX",
"VDSCX","MUOSX", "AUUAX","CLSUX","PJDAX","RYSPX","REDWX"
         ,"JHJCX","PFESX","ACUSX","NDGCX","QTSSX","QUAGX",
          "CDGCX","GALLX","VELAX","IICAX","IICHX","QSPMX",
          "IMSCX", "VOLMX","QRDTX","FLRYX","PAGHX","GCGVX",
          "AMLCX","AXSPX","AXSPX","SMDFX","FSEWX","MISEX",
          "CADVX","SGPKX","LDPCX","ACALX","SFFIX","ETLCX",
          "SGFIX","TILDX","FAPSX","JHFEX","SBQAX","SROAX",
          "VTI", "VOO", "SPY", "IVV", "VIG",
                  "ITOT", "RSP", "SCHX", "SPLG", 
                  "GSLC", "FTCS"]

#Download stock data
Stocks = yf.download(Stocks, start="2016-01-01", end="2023-04-30")

#only close
adj_close_stocks = Stocks.xs('Adj Close', level=0, axis=1)

# Define the desired column order
desired_columns = ["FRDAX", "LMMRX", "LMPIX", "MRGAX", "NSBFX",
"ITHIX",  "FDETX", "SCRLX", "AFNAX", 
"GATCX", "AEYCX", "OMSOX", "TFFCX", "GSUSX", "EVSHX",
"MCSSX","RTDYX","DRDCX","GSRLX","STRSX","MLVAX","PLJMX",
"VDSCX","MUOSX", "AUUAX","CLSUX","PJDAX","RYSPX","REDWX"
         ,"JHJCX","PFESX","ACUSX","NDGCX","QTSSX","QUAGX",
          "CDGCX","GALLX","VELAX","IICAX","IICHX","QSPMX",
          "IMSCX", "VOLMX","QRDTX","FLRYX","PAGHX","GCGVX",
          "AMLCX","AXSPX","AXSPX","SMDFX","FSEWX","MISEX",
          "CADVX","SGPKX","LDPCX","SFFIX",
          "TILDX","FAPSX","JHFEX","SBQAX"
                   
                   ,"VTI", "VOO", "SPY", "IVV", "VIG",
                  "ITOT", "RSP", "SCHX", "SPLG", 
                  "GSLC", "FTCS"]

# Reorder the columns in the dataframe
adj_close_stocks = adj_close_stocks.reindex(columns=desired_columns)

# Print the dataframe with only 'Adj Close'
adj_close_stocks
# Out:
# [*********************100%***********************]  78 of 78 completed
#
# 4 Failed downloads:
# - ETLCX: Data doesn't exist for startDate = 1451624400, endDate = 1682827200
# - ACALX: Data doesn't exist for startDate = 1451624400, endDate = 1682827200
# - SGFIX: Data doesn't exist for startDate = 1451624400, endDate = 1682827200
# - SROAX: Data doesn't exist for startDate = 1451624400, endDate = 1682827200
#                 FRDAX      LMMRX      LMPIX      MRGAX      NSBFX      ITHIX  \
# Date
# 2016-01-04  35.795307  12.609810  13.139204  17.293030  22.998016  17.886993
# 2016-01-05  35.871395  12.650180  13.165870  17.349682  23.040577  17.892292
# 2016-01-06  35.369164  12.522333  13.019214  17.094749  22.707170  17.574398
# 2016-01-07  34.661472  12.280096  12.745895  16.726511  22.210608  17.086954
# 2016-01-08  34.227737  12.179164  12.612569  16.492823  21.969418  16.869724
# ...               ...        ...        ...        ...        ...        ...
# 2023-04-24  86.599998  27.370001  28.799999  40.490002  51.770000  35.220001
# 2023-04-25  85.300003  27.049999  28.420000  39.849998  51.150002  34.619999
# 2023-04-26  84.889999  26.870001  28.280001  39.730000  50.820000  34.480000
# 2023-04-27  86.120003  27.320000  28.840000  40.439999  51.660000  35.020000
# 2023-04-28  86.790001  27.590000  29.059999  40.770000  52.160000  35.270000
#
#                 FDETX      SCRLX      AFNAX      GATCX  ...         VOO  \
# Date                                                    ...
# 2016-01-04   8.231672  20.646919  11.031862  23.584938  ...  161.455643
# 2016-01-05   8.225356  20.679239  11.100542  23.566084  ...  161.744736
# 2016-01-06   8.061100  20.415297  10.980350  23.269148  ...  159.694901
# 2016-01-07   7.827354  19.973593  10.739968  22.783691  ...  155.805420
# 2016-01-08   7.738909  19.741968  10.619775  22.576309  ...  154.149811
# ...               ...        ...        ...        ...  ...         ...
# 2023-04-24  18.809999  52.189999  22.270000  42.619999  ...  379.089996
# 2023-04-25  18.440001  51.580002  22.049999  42.139999  ...  373.100006
# 2023-04-26  18.360001  51.590000  21.790001  41.770000  ...  371.440002
# 2023-04-27  18.680000  52.759998  22.010000  42.439999  ...  378.809998
# 2023-04-28  18.860001  53.169998  22.250000  42.669998  ...  382.049988
#
#                    SPY         IVV         VIG       ITOT         RSP  \
# Date
# 2016-01-04  175.910110  177.062759   66.604179  40.160004   66.903465
# 2016-01-05  176.207672  177.430908   66.821198  40.230228   67.062370
# 2016-01-06  173.984879  175.108032   66.013840  39.659534   65.835342
# 2016-01-07  169.810745  170.918167   64.798447  38.706894   64.343498
# 2016-01-08  167.946808  169.024780   64.129967  38.250328   63.557869
# ...                ...         ...         ...        ...         ...
# 2023-04-24  411.102936  413.119446  156.889999  90.697685  145.190002
# 2023-04-25  404.577148  406.559906  154.990005  89.152321  142.720001
# 2023-04-26  402.863495  404.905121  153.669998  88.763489  141.229996
# 2023-04-27  410.883728  412.940002  156.190002  90.418526  143.550003
# 2023-04-28  414.390686  416.359314  157.570007  91.196190  145.139999
#
#                  SCHX       SPLG       GSLC       FTCS
# Date
# 2016-01-04  21.101311  20.461609  36.678513  34.278027
# 2016-01-05  21.145409  20.630169  36.757385  34.515179
# 2016-01-06  20.871994  20.323692  36.328922  34.141205
# 2016-01-07  20.373676  19.944981  35.602886  33.402363
# 2016-01-08  20.144361  19.761093  35.136787  33.001034
# ...               ...        ...        ...        ...
# 2023-04-24  48.650002  48.520000  81.800003  73.860001
# 2023-04-25  47.849998  47.750000  80.529999  73.089996
# 2023-04-26  47.669998  47.560001  80.190002  72.070000
# 2023-04-27  48.580002  48.470001  81.690002  73.029999
# 2023-04-28  48.990002  48.900002  82.349998  73.529999
#
# [1843 rows x 72 columns]

# %%
import pandas as pd

# Assuming adj_close_stocks is your DataFrame
na_values = adj_close_stocks.isna().sum()

# Filter columns with NA values
columns_with_na = na_values[na_values > 0]

# Print columns with NA values
print(columns_with_na)
# Out:
# STRSX     524
# MUOSX     101
# JHJCX     108
# PFESX    1089
# ACUSX    1278
# QTSSX    1299
# VELAX    1194
# QSPMX     920
# QRDTX    1329
# PAGHX     102
# AXSPX    1687
# AXSPX    1687
# SMDFX     922
# FSEWX    1371
# SGPKX    1114
# SFFIX    1250
# FAPSX    1682
# JHFEX    1641
# SBQAX     271
# dtype: int64

# %%
import pandas as pd

# Assuming adj_close_stocks is your DataFrame
tickers_with_na = ["STRSX", "MUOSX", "JHJCX", "PFESX", "ACUSX", "QTSSX",
                   "VELAX", "QSPMX", "QRDTX", "PAGHX", "AXSPX", "AXSPX",
                   "SMDFX", "FSEWX", "SGPKX", "SFFIX", "FAPSX", "JHFEX",
                   "SBQAX"]

# Create a new DataFrame without columns with NA values
adj_close_stocks_filtered = adj_close_stocks.drop(columns=tickers_with_na)

# Print the new DataFrame
adj_close_stocks_filtered
# Out:
#                 FRDAX      LMMRX      LMPIX      MRGAX      NSBFX      ITHIX  \
# Date
# 2016-01-04  35.795307  12.609810  13.139204  17.293030  22.998016  17.886993
# 2016-01-05  35.871395  12.650180  13.165870  17.349682  23.040577  17.892292
# 2016-01-06  35.369164  12.522333  13.019214  17.094749  22.707170  17.574398
# 2016-01-07  34.661472  12.280096  12.745895  16.726511  22.210608  17.086954
# 2016-01-08  34.227737  12.179164  12.612569  16.492823  21.969418  16.869724
# ...               ...        ...        ...        ...        ...        ...
# 2023-04-24  86.599998  27.370001  28.799999  40.490002  51.770000  35.220001
# 2023-04-25  85.300003  27.049999  28.420000  39.849998  51.150002  34.619999
# 2023-04-26  84.889999  26.870001  28.280001  39.730000  50.820000  34.480000
# 2023-04-27  86.120003  27.320000  28.840000  40.439999  51.660000  35.020000
# 2023-04-28  86.790001  27.590000  29.059999  40.770000  52.160000  35.270000
#
#                 FDETX      SCRLX      AFNAX      GATCX  ...         VOO  \
# Date                                                    ...
# 2016-01-04   8.231672  20.646919  11.031862  23.584938  ...  161.455643
# 2016-01-05   8.225356  20.679239  11.100542  23.566084  ...  161.744736
# 2016-01-06   8.061100  20.415297  10.980350  23.269148  ...  159.694901
# 2016-01-07   7.827354  19.973593  10.739968  22.783691  ...  155.805420
# 2016-01-08   7.738909  19.741968  10.619775  22.576309  ...  154.149811
# ...               ...        ...        ...        ...  ...         ...
# 2023-04-24  18.809999  52.189999  22.270000  42.619999  ...  379.089996
# 2023-04-25  18.440001  51.580002  22.049999  42.139999  ...  373.100006
# 2023-04-26  18.360001  51.590000  21.790001  41.770000  ...  371.440002
# 2023-04-27  18.680000  52.759998  22.010000  42.439999  ...  378.809998
# 2023-04-28  18.860001  53.169998  22.250000  42.669998  ...  382.049988
#
#                    SPY         IVV         VIG       ITOT         RSP  \
# Date
# 2016-01-04  175.910110  177.062759   66.604179  40.160004   66.903465
# 2016-01-05  176.207672  177.430908   66.821198  40.230228   67.062370
# 2016-01-06  173.984879  175.108032   66.013840  39.659534   65.835342
# 2016-01-07  169.810745  170.918167   64.798447  38.706894   64.343498
# 2016-01-08  167.946808  169.024780   64.129967  38.250328   63.557869
# ...                ...         ...         ...        ...         ...
# 2023-04-24  411.102936  413.119446  156.889999  90.697685  145.190002
# 2023-04-25  404.577148  406.559906  154.990005  89.152321  142.720001
# 2023-04-26  402.863495  404.905121  153.669998  88.763489  141.229996
# 2023-04-27  410.883728  412.940002  156.190002  90.418526  143.550003
# 2023-04-28  414.390686  416.359314  157.570007  91.196190  145.139999
#
#                  SCHX       SPLG       GSLC       FTCS
# Date
# 2016-01-04  21.101311  20.461609  36.678513  34.278027
# 2016-01-05  21.145409  20.630169  36.757385  34.515179
# 2016-01-06  20.871994  20.323692  36.328922  34.141205
# 2016-01-07  20.373676  19.944981  35.602886  33.402363
# 2016-01-08  20.144361  19.761093  35.136787  33.001034
# ...               ...        ...        ...        ...
# 2023-04-24  48.650002  48.520000  81.800003  73.860001
# 2023-04-25  47.849998  47.750000  80.529999  73.089996
# 2023-04-26  47.669998  47.560001  80.190002  72.070000
# 2023-04-27  48.580002  48.470001  81.690002  73.029999
# 2023-04-28  48.990002  48.900002  82.349998  73.529999
#
# [1843 rows x 53 columns]

# %%
import yfinance as yf

#Define tickers
_mf = ["FRDAX", "LMMRX", "LMPIX", "MRGAX", "NSBFX",
"ITHIX",  "FDETX", "SCRLX", "AFNAX", 
"GATCX", "AEYCX", "OMSOX", "TFFCX", "GSUSX", "EVSHX",
"MCSSX","RTDYX","DRDCX","GSRLX","STRSX","MLVAX","PLJMX",
"VDSCX","MUOSX", "AUUAX","CLSUX","PJDAX","RYSPX","REDWX"
         ,"JHJCX","PFESX","ACUSX","NDGCX","QTSSX","QUAGX",
          "CDGCX","GALLX","VELAX","IICAX","IICHX","QSPMX",
          "IMSCX", "VOLMX","QRDTX","FLRYX","PAGHX","GCGVX",
          "AMLCX","AXSPX","AXSPX","SMDFX","FSEWX","MISEX",
          "CADVX","SGPKX","LDPCX","SFFIX",
          "TILDX","FAPSX","JHFEX","SBQAX"]

ticker_mf = [ticker for ticker in _mf if ticker not in tickers_with_na]
         
ticker_etf = ["VOO", "SPY", "IVV",
              "RSP",  "SPLG"]

ticker_mf
# Out:
# ['FRDAX',
#  'LMMRX',
#  'LMPIX',
#  'MRGAX',
#  'NSBFX',
#  'ITHIX',
#  'FDETX',
#  'SCRLX',
#  'AFNAX',
#  'GATCX',
#  'AEYCX',
#  'OMSOX',
#  'TFFCX',
#  'GSUSX',
#  'EVSHX',
#  'MCSSX',
#  'RTDYX',
#  'DRDCX',
#  'GSRLX',
#  'MLVAX',
#  'PLJMX',
#  'VDSCX',
#  'AUUAX',
#  'CLSUX',
#  'PJDAX',
#  'RYSPX',
#  'REDWX',
#  'NDGCX',
#  'QUAGX',
#  'CDGCX',
#  'GALLX',
#  'IICAX',
#  'IICHX',
#  'IMSCX',
#  'VOLMX',
#  'FLRYX',
#  'GCGVX',
#  'AMLCX',
#  'MISEX',
#  'CADVX',
#  'LDPCX',
#  'TILDX']

# %%
# Assign dates
start_date_normal = '2016-01-04'
end_date_normal = '2019-12-31'
start_date_crisis = '2020-01-01'
end_date_crisis = '2023-04-28'

# %%
import pandas_datareader as pdr
import numpy as np

# Define the Treasury rate series code
treasury_rate_series = 'DGS1'

# Download Treasury rates
treasury_rates = pdr.get_data_fred(treasury_rate_series, start_date_normal, end_date_crisis)

# Print the downloaded data
rf_yearly = treasury_rates/100
rf_yearly = rf_yearly.dropna()
rf_daily = np.exp(rf_yearly / 252) - 1
rf_daily
# Out:
#                 DGS1
# DATE
# 2016-01-04  0.000024
# 2016-01-05  0.000027
# 2016-01-06  0.000027
# 2016-01-07  0.000026
# 2016-01-08  0.000025
# ...              ...
# 2023-04-24  0.000189
# 2023-04-25  0.000183
# 2023-04-26  0.000184
# 2023-04-27  0.000190
# 2023-04-28  0.000190
#
# [1832 rows x 1 columns]

# %%
daily_returns = adj_close_stocks_filtered.pct_change()
daily_returns = daily_returns.iloc[1:]
daily_returns
# Out:
#                FRDAX     LMMRX     LMPIX     MRGAX     NSBFX     ITHIX  \
# Date
# 2016-01-05  0.002126  0.003201  0.002029  0.003276  0.001851  0.000296
# 2016-01-06 -0.014001 -0.010106 -0.011139 -0.014694 -0.014470 -0.017767
# 2016-01-07 -0.020009 -0.019344 -0.020993 -0.021541 -0.021868 -0.027736
# 2016-01-08 -0.012513 -0.008219 -0.010460 -0.013971 -0.010859 -0.012713
# 2016-01-11 -0.001779  0.001657  0.001586 -0.001288  0.003552 -0.000942
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  0.002895  0.001464  0.000695  0.000989  0.001741  0.000853
# 2023-04-25 -0.015011 -0.011692 -0.013194 -0.015806 -0.011976 -0.017036
# 2023-04-26 -0.004807 -0.006654 -0.004926 -0.003011 -0.006452 -0.004044
# 2023-04-27  0.014489  0.016747  0.019802  0.017871  0.016529  0.015661
# 2023-04-28  0.007780  0.009883  0.007628  0.008160  0.009679  0.007139
#
#                FDETX     SCRLX     AFNAX     GATCX  ...       VOO       SPY  \
# Date                                                ...
# 2016-01-05 -0.000767  0.001565  0.006226 -0.000799  ...  0.001791  0.001692
# 2016-01-06 -0.019969 -0.012764 -0.010828 -0.012600  ... -0.012673 -0.012615
# 2016-01-07 -0.028997 -0.021636 -0.021892 -0.020863  ... -0.024356 -0.023991
# 2016-01-08 -0.011299 -0.011597 -0.011191 -0.009102  ... -0.010626 -0.010977
# 2016-01-11 -0.004898  0.001637  0.002425 -0.001461  ...  0.000114  0.000990
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-04-24  0.003200  0.000959  0.003153  0.001410  ...  0.001321  0.001043
# 2023-04-25 -0.019670 -0.011688 -0.009879 -0.011262  ... -0.015801 -0.015874
# 2023-04-26 -0.004338  0.000194 -0.011791 -0.008780  ... -0.004449 -0.004236
# 2023-04-27  0.017429  0.022679  0.010096  0.016040  ...  0.019842  0.019908
# 2023-04-28  0.009636  0.007771  0.010904  0.005419  ...  0.008553  0.008535
#
#                  IVV       VIG      ITOT       RSP      SCHX      SPLG  \
# Date
# 2016-01-05  0.002079  0.003258  0.001749  0.002375  0.002090  0.008238
# 2016-01-06 -0.013092 -0.012082 -0.014186 -0.018297 -0.012930 -0.014856
# 2016-01-07 -0.023927 -0.018411 -0.024020 -0.022660 -0.023875 -0.018634
# 2016-01-08 -0.011078 -0.010316 -0.011795 -0.012210 -0.011255 -0.009220
# 2016-01-11  0.001037  0.002166 -0.000229 -0.003194 -0.000219 -0.004431
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  0.001256  0.002236  0.000440  0.001863  0.000617  0.001032
# 2023-04-25 -0.015878 -0.012110 -0.017039 -0.017012 -0.016444 -0.015870
# 2023-04-26 -0.004070 -0.008517 -0.004361 -0.010440 -0.003762 -0.003979
# 2023-04-27  0.019844  0.016399  0.018645  0.016427  0.019090  0.019134
# 2023-04-28  0.008280  0.008835  0.008601  0.011076  0.008440  0.008871
#
#                 GSLC      FTCS
# Date
# 2016-01-05  0.002150  0.006918
# 2016-01-06 -0.011657 -0.010835
# 2016-01-07 -0.019985 -0.021641
# 2016-01-08 -0.013092 -0.012015
# 2016-01-11  0.002781 -0.000829
# ...              ...       ...
# 2023-04-24  0.001224  0.003396
# 2023-04-25 -0.015526 -0.010425
# 2023-04-26 -0.004222 -0.013955
# 2023-04-27  0.018706  0.013320
# 2023-04-28  0.008079  0.006847
#
# [1842 rows x 53 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Select the returns of mutual funds (MF)
mf_returns = daily_returns[ticker_mf]

# Select the returns of ETFs
etf_returns = daily_returns[ticker_etf]

# Calculate the average returns for MF and ETF
mf_avg_return = mf_returns.mean()
etf_avg_return = etf_returns.mean()

# Create a DataFrame to store the average returns
avg_returns = pd.DataFrame({'MF': mf_avg_return, 'ETF': etf_avg_return})

# Plot the average returns
avg_returns.plot(kind='bar')
plt.xlabel('Category')
plt.ylabel('Average Return')
plt.title('Average Returns of MF vs ETF')
plt.legend()
plt.show()

# %%
import pandas as pd

# First, let's isolate the relevant data
etf_df = daily_returns[ticker_etf].copy()
mf_df = daily_returns[ticker_mf].copy()

# Then, create equally weighted portfolio returns
etf_portfolio_returns = etf_df.mean(axis=1)
mf_portfolio_returns = mf_df.mean(axis=1)

# %%
import yfinance as yf

# Download S&P 500 data (only Adj Close) from 2016 to present
ticker = '^SP500TR'  # Ticker symbol for S&P 500
start_date = '2016-01-01'
end_date = '2023-04-29'
sp500_adjclose = yf.download(ticker, start=start_date, end=end_date)['Adj Close']
sp500_returns = sp500_adjclose.pct_change().dropna()
sp500_returns
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2016-01-05    0.002014
# 2016-01-06   -0.012761
# 2016-01-07   -0.023674
# 2016-01-08   -0.010833
# 2016-01-11    0.000851
#                 ...
# 2023-04-24    0.000852
# 2023-04-25   -0.015769
# 2023-04-26   -0.003836
# 2023-04-27    0.019591
# 2023-04-28    0.008361
# Name: Adj Close, Length: 1842, dtype: float64

# %%
rf_daily_aligned = rf_daily.reindex(daily_returns.index)
etf_excess_returns = etf_portfolio_returns.sub(rf_daily_aligned['DGS1'], axis=0)  
mf_excess_returns = mf_portfolio_returns.sub(rf_daily_aligned['DGS1'], axis=0)
sp500_excess_returns = sp500_returns.sub(rf_daily_aligned['DGS1'], axis=0)
sp500_excess_returns
# Out:
# Date
# 2016-01-05    0.001987
# 2016-01-06   -0.012788
# 2016-01-07   -0.023701
# 2016-01-08   -0.010858
# 2016-01-11    0.000826
#                 ...
# 2023-04-24    0.000663
# 2023-04-25   -0.015951
# 2023-04-26   -0.004020
# 2023-04-27    0.019401
# 2023-04-28    0.008170
# Length: 1842, dtype: float64

# %%
normal_sp500_excess_returns = sp500_excess_returns.loc[start_date_normal:end_date_normal]
normal_etf_excess_returns = etf_excess_returns.loc[start_date_normal:end_date_normal]
crisis_sp500_excess_returns = sp500_excess_returns.loc[start_date_crisis:end_date_crisis]
crisis_etf_excess_returns = etf_excess_returns.loc[start_date_crisis:end_date_crisis]

# %%
import pandas as pd
from scipy import stats
# Filter your returns
normal_sp500_excess_returns = sp500_excess_returns.loc[start_date_normal:end_date_normal]
normal_etf_excess_returns = etf_excess_returns.loc[start_date_normal:end_date_normal]

combined_returns = pd.concat([normal_sp500_excess_returns, normal_etf_excess_returns], axis=1).dropna()

# Perform linear regression to calculate beta and intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(combined_returns.iloc[:, 0], combined_returns.iloc[:, 1])

# Store the results in a DataFrame
CAPM_etf_normal = pd.DataFrame({'Fund': ['ETF Normal'], 'Beta': [slope], 'Alpha': [intercept], 
                      'R-Squared': [r_value], 'p-value': [p_value], 'Std Error': [std_err]})
CAPM_etf_normal
# Out:
#          Fund      Beta    Alpha  R-Squared  p-value  Std Error
# 0  ETF Normal  0.987198 -0.00001   0.995656      0.0   0.002925

# %%
# Filter your returns
crisis_sp500_excess_returns = sp500_excess_returns.loc[start_date_crisis:end_date_crisis]
crisis_etf_excess_returns = etf_excess_returns.loc[start_date_crisis:end_date_crisis]

combined_returns = pd.concat([crisis_sp500_excess_returns, crisis_etf_excess_returns], axis=1).dropna()

# Perform linear regression to calculate beta and intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(combined_returns.iloc[:, 0], combined_returns.iloc[:, 1])

# Store the results in a DataFrame
CAPM_etf_crisis = pd.DataFrame({'Fund': ['ETF Crisis'], 'Beta': [slope], 'Alpha': [intercept], 
                      'R-Squared': [r_value], 'p-value': [p_value], 'Std Error': [std_err]})
CAPM_etf_crisis
# Out:
#          Fund      Beta     Alpha  R-Squared  p-value  Std Error
# 0  ETF Crisis  0.994578  0.000002   0.997454      0.0    0.00247

# %%
# Filter your returns
normal_sp500_excess_returns = sp500_excess_returns.loc[start_date_normal:end_date_normal]
normal_mf_excess_returns = mf_excess_returns.loc[start_date_normal:end_date_normal]

combined_returns = pd.concat([normal_sp500_excess_returns, normal_mf_excess_returns], axis=1).dropna()

# Perform linear regression to calculate beta and intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(combined_returns.iloc[:, 0], combined_returns.iloc[:, 1])

# Store the results in a DataFrame
CAPM_mf_normal = pd.DataFrame({'Fund': ['MF Normal'], 'Beta': [slope], 'Alpha': [intercept], 
                      'R-Squared': [r_value], 'p-value': [p_value], 'Std Error': [std_err]})
CAPM_mf_normal
# Out:
#         Fund      Beta     Alpha  R-Squared  p-value  Std Error
# 0  MF Normal  0.968721 -0.000057   0.996686      0.0   0.002505

# %%
# Filter your returns
crisis_sp500_excess_returns = sp500_excess_returns.loc[start_date_crisis:end_date_crisis]
crisis_mf_excess_returns = mf_excess_returns.loc[start_date_crisis:end_date_crisis]

combined_returns = pd.concat([crisis_sp500_excess_returns, crisis_mf_excess_returns], axis=1).dropna()

# Perform linear regression to calculate beta and intercept
slope, intercept, r_value, p_value, std_err = stats.linregress(combined_returns.iloc[:, 0], combined_returns.iloc[:, 1])

# Store the results in a DataFrame
CAPM_mf_crisis = pd.DataFrame({'Fund': ['MF Crisis'], 'Beta': [slope], 'Alpha': [intercept], 
                      'R-Squared': [r_value], 'p-value': [p_value], 'Std Error': [std_err]})
CAPM_mf_crisis
# Out:
#         Fund      Beta     Alpha  R-Squared  p-value  Std Error
# 0  MF Crisis  0.967222 -0.000051   0.996364      0.0   0.002872

# %%
data_crisis = pd.concat([crisis_sp500_excess_returns, crisis_mf_excess_returns, crisis_etf_excess_returns], axis=1)
data_normal = pd.concat([normal_sp500_excess_returns, normal_mf_excess_returns, normal_etf_excess_returns], axis=1)
# Assign custom column names
data_crisis.columns = ['SP500 Excess Returns', 'MF Excess Returns', 'ETF Excess Returns']
# Assign custom column names
data_normal.columns = ['SP500 Excess Returns', 'MF Excess Returns', 'ETF Excess Returns']
data_normal
# Out:
#             SP500 Excess Returns  MF Excess Returns  ETF Excess Returns
# Date
# 2016-01-05              0.001987           0.001420            0.003208
# 2016-01-06             -0.012788          -0.013278           -0.014333
# 2016-01-07             -0.023701          -0.023043           -0.022740
# 2016-01-08             -0.010858          -0.011442           -0.010847
# 2016-01-11              0.000826          -0.000183           -0.001122
# ...                          ...                ...                 ...
# 2019-12-24             -0.000186           0.000065            0.000003
# 2019-12-26              0.005161           0.004202            0.004661
# 2019-12-27             -0.000011           0.000924           -0.000581
# 2019-12-30             -0.005711          -0.006324           -0.004984
# 2019-12-31              0.002946           0.002415            0.002614
#
# [1005 rows x 3 columns]

# %%
import statsmodels.api as sm

# Add a constant column for the intercept term
data_crisis = sm.add_constant(data_crisis)
data_normal = sm.add_constant(data_normal)

# Drop rows with missing values
data_crisis = data_crisis.dropna()
data_normal = data_normal.dropna()

# Fit the linear regression models for each case
model_crisis = sm.OLS(data_crisis['MF Excess Returns'], data_crisis[['const', 'SP500 Excess Returns']])
model_normal = sm.OLS(data_normal['MF Excess Returns'], data_normal[['const', 'SP500 Excess Returns']])

results_crisis_mf = model_crisis.fit()
results_normal_mf = model_normal.fit()

# Print the regression results
print("Crisis Regression Results:")
print(results_crisis_mf.summary())
print()
print("Normal Regression Results:")
print(results_normal_mf.summary())
# Out:
# Crisis Regression Results:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MF Excess Returns   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 1.134e+05
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:27   Log-Likelihood:                 4351.0
# No. Observations:                 831   AIC:                            -8698.
# Df Residuals:                     829   BIC:                            -8688.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -5.055e-05   4.47e-05     -1.130      0.259      -0.000    3.73e-05
# SP500 Excess Returns     0.9672      0.003    336.738      0.000       0.962       0.973
# ==============================================================================
# Omnibus:                       43.586   Durbin-Watson:                   1.972
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.183
# Skew:                          -0.290   Prob(JB):                     2.90e-22
# Kurtosis:                       4.590   Cond. No.                         64.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Normal Regression Results:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MF Excess Returns   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 1.495e+05
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:27   Log-Likelihood:                 5923.0
# No. Observations:                 998   AIC:                        -1.184e+04
# Df Residuals:                     996   BIC:                        -1.183e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -5.749e-05   2.03e-05     -2.828      0.005   -9.74e-05   -1.76e-05
# SP500 Excess Returns     0.9687      0.003    386.663      0.000       0.964       0.974
# ==============================================================================
# Omnibus:                      178.394   Durbin-Watson:                   2.266
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3290.300
# Skew:                           0.170   Prob(JB):                         0.00
# Kurtosis:                      11.889   Cond. No.                         124.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm

# Assuming you have the following DataFrames:
# market_excess_returns_crisis, market_excess_returns_normal
# mf_portfolio_excess_returns_crisis, mf_portfolio_excess_returns_normal
# etf_portfolio_excess_returns_crisis, etf_portfolio_excess_returns_normal

# Add a constant column for the intercept term
data_crisis = sm.add_constant(data_crisis)
data_normal = sm.add_constant(data_normal)

# Drop rows with missing values
data_crisis = data_crisis.dropna()
data_normal = data_normal.dropna()

# Fit the linear regression models for each case
model_crisis = sm.OLS(data_crisis['ETF Excess Returns'], data_crisis[['const', 'SP500 Excess Returns']])
model_normal = sm.OLS(data_normal['ETF Excess Returns'], data_normal[['const', 'SP500 Excess Returns']])

results_crisis_etf = model_crisis.fit()
results_normal_etf = model_normal.fit()

# Print the regression results
print("Crisis Regression Results:")
print(results_crisis_etf.summary())
print()
print("Normal RegressionResults:")
print(results_normal_etf.summary())
# Out:
# Crisis Regression Results:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ETF Excess Returns   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 1.622e+05
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:27   Log-Likelihood:                 4476.5
# No. Observations:                 831   AIC:                            -8949.
# Df Residuals:                     829   BIC:                            -8940.
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 1.809e-06   3.85e-05      0.047      0.963   -7.37e-05    7.73e-05
# SP500 Excess Returns     0.9946      0.002    402.726      0.000       0.990       0.999
# ==============================================================================
# Omnibus:                       95.464   Durbin-Watson:                   2.002
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              511.217
# Skew:                           0.356   Prob(JB):                    9.78e-112
# Kurtosis:                       6.776   Cond. No.                         64.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Normal RegressionResults:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ETF Excess Returns   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                 1.139e+05
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:27   Log-Likelihood:                 5768.4
# No. Observations:                 998   AIC:                        -1.153e+04
# Df Residuals:                     996   BIC:                        -1.152e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -1.026e-05   2.37e-05     -0.432      0.666   -5.68e-05    3.63e-05
# SP500 Excess Returns     0.9872      0.003    337.485      0.000       0.981       0.993
# ==============================================================================
# Omnibus:                      187.267   Durbin-Watson:                   2.602
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3843.241
# Skew:                           0.183   Prob(JB):                         0.00
# Kurtosis:                      12.607   Cond. No.                         124.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import pandas_datareader.data as web
# Retrieve SMB data from the Kenneth R. French Data Library
smbhml_data_crisis = web.DataReader('F-F_Research_Data_5_Factors_2x3_daily', 'famafrench', start_date_crisis, end_date_crisis)
SMB_crisis = smbhml_data_crisis[0]['SMB']
HML_crisis = smbhml_data_crisis[0]['HML']
smbhml_data_normal = web.DataReader('F-F_Research_Data_5_Factors_2x3_daily', 'famafrench', start_date_normal, end_date_normal)
SMB_normal = smbhml_data_normal[0]['SMB']
HML_normal = smbhml_data_normal[0]['HML']
SMB_normal = SMB_normal.iloc[1:]
HML_normal = HML_normal.iloc[1:]
SMB_crisis
# Out:
# Date
# 2020-01-02   -0.97
# 2020-01-03    0.30
# 2020-01-06   -0.21
# 2020-01-07   -0.03
# 2020-01-08   -0.17
#               ...
# 2023-04-24   -0.27
# 2023-04-25   -0.83
# 2023-04-26   -0.04
# 2023-04-27   -0.59
# 2023-04-28    0.21
# Name: SMB, Length: 837, dtype: float64

# %%
data_normal
# Out:
#             const  SP500 Excess Returns  MF Excess Returns  ETF Excess Returns
# Date
# 2016-01-05    1.0              0.001987           0.001420            0.003208
# 2016-01-06    1.0             -0.012788          -0.013278           -0.014333
# 2016-01-07    1.0             -0.023701          -0.023043           -0.022740
# 2016-01-08    1.0             -0.010858          -0.011442           -0.010847
# 2016-01-11    1.0              0.000826          -0.000183           -0.001122
# ...           ...                   ...                ...                 ...
# 2019-12-24    1.0             -0.000186           0.000065            0.000003
# 2019-12-26    1.0              0.005161           0.004202            0.004661
# 2019-12-27    1.0             -0.000011           0.000924           -0.000581
# 2019-12-30    1.0             -0.005711          -0.006324           -0.004984
# 2019-12-31    1.0              0.002946           0.002415            0.002614
#
# [998 rows x 4 columns]

# %%
import statsmodels.api as sm

# Assuming you have the following DataFrames:
# data_crisis, data_normal
# SMB_crisis, HML_crisis, SMB_normal, HML_normal

# Add a constant column for the intercept term
data_crisis = sm.add_constant(data_crisis)
data_normal = sm.add_constant(data_normal)

# Drop rows with missing values
data_crisis = data_crisis.dropna()
data_normal = data_normal.dropna()

# Merge the SMB and HML factor data with the main data
data_crisis = data_crisis.merge(SMB_crisis, left_index=True, right_index=True)
data_crisis = data_crisis.merge(HML_crisis, left_index=True, right_index=True)
data_normal = data_normal.merge(SMB_normal, left_index=True, right_index=True)
data_normal = data_normal.merge(HML_normal, left_index=True, right_index=True)

# Fit the Fama-French three-factor regression models for each case
model_crisis = sm.OLS(data_crisis['MF Excess Returns'], data_crisis[['const', 'SP500 Excess Returns', 'SMB', 'HML']])
model_normal = sm.OLS(data_normal['MF Excess Returns'], data_normal[['const', 'SP500 Excess Returns', 'SMB', 'HML']])

results_crisis_mf_ff3 = model_crisis.fit()
results_normal_mf_ff3 = model_normal.fit()

# Print the regression results
print("Crisis Regression Results (Fama-French 3-Factor Model):")
print(results_crisis_mf_ff3.summary())
print()
print("Normal Regression Results (Fama-French 3-Factor Model):")
print(results_normal_mf_ff3.summary())
# Out:
# Crisis Regression Results (Fama-French 3-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MF Excess Returns   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 6.502e+04
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:41   Log-Likelihood:                 4576.1
# No. Observations:                 831   AIC:                            -9144.
# Df Residuals:                     827   BIC:                            -9125.
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 -5.21e-05   3.42e-05     -1.525      0.128      -0.000     1.5e-05
# SP500 Excess Returns     0.9640      0.002    433.078      0.000       0.960       0.968
# SMB                      0.0005   4.32e-05     11.168      0.000       0.000       0.001
# HML                      0.0005   2.75e-05     17.030      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                       62.125   Durbin-Watson:                   2.027
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              156.436
# Skew:                          -0.399   Prob(JB):                     1.07e-34
# Kurtosis:                       4.970   Cond. No.                         88.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Normal Regression Results (Fama-French 3-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MF Excess Returns   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 6.833e+04
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:41   Log-Likelihood:                 6080.7
# No. Observations:                 998   AIC:                        -1.215e+04
# Df Residuals:                     994   BIC:                        -1.213e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -4.844e-05   1.74e-05     -2.786      0.005   -8.26e-05   -1.43e-05
# SP500 Excess Returns     0.9651      0.002    444.712      0.000       0.961       0.969
# SMB                      0.0006   3.48e-05     17.584      0.000       0.001       0.001
# HML                      0.0002   3.11e-05      5.646      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                      256.103   Durbin-Watson:                   2.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14545.557
# Skew:                           0.134   Prob(JB):                         0.00
# Kurtosis:                      21.701   Cond. No.                         125.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Fit the Fama-French three-factor regression models for each case
model_crisis = sm.OLS(data_crisis['ETF Excess Returns'], data_crisis[['const', 'SP500 Excess Returns', 'SMB', 'HML']])
model_normal = sm.OLS(data_normal['ETF Excess Returns'], data_normal[['const', 'SP500 Excess Returns', 'SMB', 'HML']])

results_crisis_etf_ff3 = model_crisis.fit()
results_normal_etf_ff3 = model_normal.fit()

# Print the regression results
print("Crisis Regression Results (Fama-French 3-Factor Model):")
print(results_crisis_etf_ff3.summary())
print()
print("Normal Regression Results (Fama-French 3-Factor Model):")
print(results_normal_etf_ff3.summary())
# Out:
# Crisis Regression Results (Fama-French 3-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ETF Excess Returns   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 1.216e+05
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:41   Log-Likelihood:                 4813.2
# No. Observations:                 831   AIC:                            -9618.
# Df Residuals:                     827   BIC:                            -9599.
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                  1.68e-07   2.57e-05      0.007      0.995   -5.03e-05    5.06e-05
# SP500 Excess Returns     0.9916      0.002    592.566      0.000       0.988       0.995
# SMB                      0.0005   3.25e-05     14.053      0.000       0.000       0.001
# HML                      0.0005   2.06e-05     22.966      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                      143.499   Durbin-Watson:                   2.325
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2215.429
# Skew:                          -0.213   Prob(JB):                         0.00
# Kurtosis:                      10.988   Cond. No.                         88.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Normal Regression Results (Fama-French 3-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ETF Excess Returns   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 4.440e+04
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:41   Log-Likelihood:                 5846.9
# No. Observations:                 998   AIC:                        -1.169e+04
# Df Residuals:                     994   BIC:                        -1.167e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -2.423e-06    2.2e-05     -0.110      0.912   -4.55e-05    4.07e-05
# SP500 Excess Returns     0.9843      0.003    358.856      0.000       0.979       0.990
# SMB                      0.0005   4.39e-05     11.645      0.000       0.000       0.001
# HML                      0.0002   3.93e-05      4.403      0.000    9.58e-05       0.000
# ==============================================================================
# Omnibus:                      235.664   Durbin-Watson:                   2.732
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9481.953
# Skew:                           0.185   Prob(JB):                         0.00
# Kurtosis:                      18.096   Cond. No.                         125.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Retrieve momentum data from the Kenneth R. French Data Library
momentum_data_crisis = web.DataReader('F-F_Momentum_Factor_daily', 'famafrench', start_date_crisis, end_date_crisis)
MOM_crisis = momentum_data_crisis[0]['Mom   ']
momentum_data_normal = web.DataReader('F-F_Momentum_Factor_daily', 'famafrench', start_date_normal, end_date_normal)
MOM_normal = momentum_data_normal[0]['Mom   ']

# %%
MOM_normal
# Out:
# Date
# 2016-01-04   -1.93
# 2016-01-05    0.67
# 2016-01-06    1.92
# 2016-01-07    0.86
# 2016-01-08   -0.11
#               ...
# 2019-12-24    0.16
# 2019-12-26    0.30
# 2019-12-27    0.37
# 2019-12-30    0.05
# 2019-12-31   -0.46
# Name: Mom   , Length: 1006, dtype: float64

# %%
# Merge the and MOM factor data with the main data
data_crisis = data_crisis.merge(MOM_crisis, left_index=True, right_index=True)
data_normal = data_normal.merge(MOM_normal, left_index=True, right_index=True)

# %%
data_normal
# Out:
#             const  SP500 Excess Returns  MF Excess Returns  \
# Date
# 2016-01-05    1.0              0.001987           0.001420
# 2016-01-06    1.0             -0.012788          -0.013278
# 2016-01-07    1.0             -0.023701          -0.023043
# 2016-01-08    1.0             -0.010858          -0.011442
# 2016-01-11    1.0              0.000826          -0.000183
# ...           ...                   ...                ...
# 2019-12-24    1.0             -0.000186           0.000065
# 2019-12-26    1.0              0.005161           0.004202
# 2019-12-27    1.0             -0.000011           0.000924
# 2019-12-30    1.0             -0.005711          -0.006324
# 2019-12-31    1.0              0.002946           0.002415
#
#             ETF Excess Returns   SMB   HML  Mom
# Date
# 2016-01-05            0.003208 -0.24  0.01    0.67
# 2016-01-06           -0.014333 -0.23  0.00    1.92
# 2016-01-07           -0.022740 -0.29  0.08    0.86
# 2016-01-08           -0.010847 -0.51 -0.03   -0.11
# 2016-01-11           -0.001122 -0.62  0.40    1.61
# ...                        ...   ...   ...     ...
# 2019-12-24            0.000003  0.37 -0.01    0.16
# 2019-12-26            0.004661 -0.56  0.00    0.30
# 2019-12-27           -0.000581 -0.55 -0.07    0.37
# 2019-12-30           -0.004984  0.28  0.56    0.05
# 2019-12-31            0.002614  0.01  0.11   -0.46
#
# [998 rows x 7 columns]

# %%
data_crisis = data_crisis.rename(columns={'Mom   ': 'MOM'})
data_normal = data_normal.rename(columns={'Mom   ': 'MOM'})

# %%
column_names = data_crisis.columns
print(column_names)
# Out:
# Index(['const', 'SP500 Excess Returns', 'MF Excess Returns',
#        'ETF Excess Returns', 'SMB', 'HML', 'MOM'],
#       dtype='object')

# %%
import statsmodels.api as sm

# Assuming you have the following DataFrames:
# data_crisis, data_normal
# SMB_crisis, HML_crisis, SMB_normal, HML_normal, MOM_crisis, MOM_normal

# Drop rows with missing values
data_crisis = data_crisis.dropna()
data_normal = data_normal.dropna()

# Fit the Carhart four-factor regression models for each case
model_crisis = sm.OLS(data_crisis['ETF Excess Returns'], data_crisis[['const', 'SP500 Excess Returns', 'SMB', 'HML', 'MOM']])
model_normal = sm.OLS(data_normal['ETF Excess Returns'], data_normal[['const', 'SP500 Excess Returns', 'SMB', 'HML', 'MOM']])

results_crisis_etf_ff4 = model_crisis.fit()
results_normal_etf_ff4 = model_normal.fit()

# Print the regression results
print("Crisis Regression Results (Carhart 4-Factor Model):")
print(results_crisis_etf_ff4.summary())
print()
print("Normal Regression Results (Carhart 4-Factor Model):")
print(results_normal_etf_ff4.summary())
# Out:
# Crisis Regression Results (Carhart 4-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ETF Excess Returns   R-squared:                       0.998
# Model:                            OLS   Adj. R-squared:                  0.998
# Method:                 Least Squares   F-statistic:                 1.013e+05
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:45   Log-Likelihood:                 4857.2
# No. Observations:                 831   AIC:                            -9704.
# Df Residuals:                     826   BIC:                            -9681.
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -2.839e-07   2.44e-05     -0.012      0.991   -4.81e-05    4.76e-05
# SP500 Excess Returns     0.9887      0.002    612.145      0.000       0.986       0.992
# SMB                      0.0004   3.16e-05     12.244      0.000       0.000       0.000
# HML                      0.0004      2e-05     21.912      0.000       0.000       0.000
# MOM                     -0.0002   1.71e-05     -9.609      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                      143.885   Durbin-Watson:                   2.290
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2142.731
# Skew:                          -0.243   Prob(JB):                         0.00
# Kurtosis:                      10.852   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Normal Regression Results (Carhart 4-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     ETF Excess Returns   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                 3.451e+04
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:45   Log-Likelihood:                 5865.1
# No. Observations:                 998   AIC:                        -1.172e+04
# Df Residuals:                     993   BIC:                        -1.170e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -3.736e-06   2.16e-05     -0.173      0.863   -4.61e-05    3.86e-05
# SP500 Excess Returns     0.9827      0.003    362.918      0.000       0.977       0.988
# SMB                      0.0004   4.52e-05      9.500      0.000       0.000       0.001
# HML                   6.311e-05   4.26e-05      1.481      0.139   -2.05e-05       0.000
# MOM                     -0.0002   3.34e-05     -6.068      0.000      -0.000      -0.000
# ==============================================================================
# Omnibus:                      242.822   Durbin-Watson:                   2.768
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            10145.596
# Skew:                           0.236   Prob(JB):                         0.00
# Kurtosis:                      18.613   Cond. No.                         126.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
import statsmodels.api as sm

# Assuming you have the following DataFrames:
# data_crisis, data_normal
# SMB_crisis, HML_crisis, SMB_normal, HML_normal, MOM_crisis, MOM_normal

# Drop rows with missing values
data_crisis = data_crisis.dropna()
data_normal = data_normal.dropna()

# Fit the Carhart four-factor regression models for each case
model_crisis = sm.OLS(data_crisis['MF Excess Returns'], data_crisis[['const', 'SP500 Excess Returns', 'SMB', 'HML', 'MOM']])
model_normal = sm.OLS(data_normal['MF Excess Returns'], data_normal[['const', 'SP500 Excess Returns', 'SMB', 'HML', 'MOM']])

results_crisis_mf_ff4 = model_crisis.fit()
results_normal_mf_ff4 = model_normal.fit()

# Print the regression results
print("Crisis Regression Results (Carhart 4-Factor Model):")
print(results_crisis_mf_ff4.summary())
print()
print("Normal Regression Results (Carhart 4-Factor Model):")
print(results_normal_mf_ff4.summary())
# Out:
# Crisis Regression Results (Carhart 4-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MF Excess Returns   R-squared:                       0.996
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 5.298e+04
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:45   Log-Likelihood:                 4610.9
# No. Observations:                 831   AIC:                            -9212.
# Df Residuals:                     826   BIC:                            -9188.
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -5.157e-05   3.28e-05     -1.573      0.116      -0.000    1.28e-05
# SP500 Excess Returns     0.9674      0.002    445.274      0.000       0.963       0.972
# SMB                      0.0006   4.25e-05     13.262      0.000       0.000       0.001
# HML                      0.0005   2.69e-05     19.046      0.000       0.000       0.001
# MOM                      0.0002    2.3e-05      8.496      0.000       0.000       0.000
# ==============================================================================
# Omnibus:                       57.095   Durbin-Watson:                   2.078
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              173.111
# Skew:                          -0.292   Prob(JB):                     2.57e-38
# Kurtosis:                       5.159   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Normal Regression Results (Carhart 4-Factor Model):
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      MF Excess Returns   R-squared:                       0.995
# Model:                            OLS   Adj. R-squared:                  0.995
# Method:                 Least Squares   F-statistic:                 5.121e+04
# Date:                Mon, 19 Jun 2023   Prob (F-statistic):               0.00
# Time:                        08:10:45   Log-Likelihood:                 6080.8
# No. Observations:                 998   AIC:                        -1.215e+04
# Df Residuals:                     993   BIC:                        -1.213e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -4.835e-05   1.74e-05     -2.780      0.006   -8.25e-05   -1.42e-05
# SP500 Excess Returns     0.9652      0.002    442.457      0.000       0.961       0.969
# SMB                      0.0006   3.64e-05     16.922      0.000       0.001       0.001
# HML                      0.0002   3.43e-05      5.320      0.000       0.000       0.000
# MOM                   1.326e-05   2.69e-05      0.493      0.622   -3.95e-05     6.6e-05
# ==============================================================================
# Omnibus:                      256.161   Durbin-Watson:                   2.307
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            14592.490
# Skew:                           0.131   Prob(JB):                         0.00
# Kurtosis:                      21.731   Cond. No.                         126.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
alpha_mf_crisis, beta_mf_crisis = results_crisis_mf.params
alpha_etf_crisis, beta_etf_crisis = results_crisis_etf.params
se_alpha_mf_crisis = results_crisis_mf.bse[0]  # Assuming alpha is the first parameter
se_alpha_etf_crisis = results_crisis_etf.bse[0]  # Assuming alpha is the first parameter
alpha_mf_normal, beta_mf_normal = results_normal_mf.params
alpha_etf_normal, beta_etf_normal = results_normal_etf.params
se_alpha_mf_normal = results_normal_mf.bse[0]  # Assuming alpha is the first parameter
se_alpha_etf_normal = results_normal_etf.bse[0]

# Calculate the difference in alphas between ETF and MF for both crisis and normal periods
delta_alpha_crisis = alpha_etf_crisis - alpha_mf_crisis
delta_alpha_normal = alpha_etf_normal - alpha_mf_normal

# Calculate the standard error for the difference in alphas (se_delta_alpha)
se_delta_alpha_crisis = np.sqrt(se_alpha_etf_crisis**2 + se_alpha_mf_crisis**2)
se_delta_alpha_normal = np.sqrt(se_alpha_etf_normal**2 + se_alpha_mf_normal**2)

# Calculate the t-statistic for the difference in alpha differences between crisis and normal periods
t_delta_alpha = (delta_alpha_crisis - delta_alpha_normal) / np.sqrt(se_delta_alpha_crisis**2 + se_delta_alpha_normal**2)

# Assuming you are pooling the degrees of freedom (df) for both crisis and normal periods, 
# calculate the corresponding p-value
df = results_crisis_mf.df_resid + results_crisis_etf.df_resid
p_delta_alpha = 2 * (1 - stats.t.cdf(np.abs(t_delta_alpha), df=df))

# Print the t-statistic and p-value
print("Difference in Alphas t-statistic:", t_delta_alpha, "p-value:", p_delta_alpha)
# Out:
# Difference in Alphas t-statistic: 0.07675714741799669 p-value: 0.9388260024263817

# %%
import scipy.stats as stats

# Get parameters and standard errors from your models
alpha_mf_crisis, beta_mf_crisis = results_crisis_mf.params
alpha_etf_crisis, beta_etf_crisis = results_crisis_etf.params
alpha_mf_normal, beta_mf_normal = results_normal_mf.params
alpha_etf_normal, beta_etf_normal = results_normal_etf.params

se_alpha_mf_crisis, se_beta_mf_crisis = results_crisis_mf.bse
se_alpha_etf_crisis, se_beta_etf_crisis = results_crisis_etf.bse
se_alpha_mf_normal, se_beta_mf_normal = results_normal_mf.bse
se_alpha_etf_normal, se_beta_etf_normal = results_normal_etf.bse

# Calculate the t-statistics for the difference in alphas and betas between crisis and normal periods
t_alpha_mf = (alpha_mf_crisis - alpha_mf_normal) / np.sqrt(se_alpha_mf_crisis**2 + se_alpha_mf_normal**2)
t_beta_mf = (beta_mf_crisis - beta_mf_normal) / np.sqrt(se_beta_mf_crisis**2 + se_beta_mf_normal**2)

t_alpha_etf = (alpha_etf_crisis - alpha_etf_normal) / np.sqrt(se_alpha_etf_crisis**2 + se_alpha_etf_normal**2)
t_beta_etf = (beta_etf_crisis - beta_etf_normal) / np.sqrt(se_beta_etf_crisis**2 + se_beta_etf_normal**2)

# Calculate the corresponding p-values
p_alpha_mf = 2 * (1 - stats.t.cdf(np.abs(t_alpha_mf), df=results_crisis_mf.df_resid))
p_beta_mf = 2 * (1 - stats.t.cdf(np.abs(t_beta_mf), df=results_crisis_mf.df_resid))

p_alpha_etf = 2 * (1 - stats.t.cdf(np.abs(t_alpha_etf), df=results_crisis_etf.df_resid))
p_beta_etf = 2 * (1 - stats.t.cdf(np.abs(t_beta_etf), df=results_crisis_etf.df_resid))

# Print the t-statistics and p-values
print("MF Alpha t-statistic:", t_alpha_mf, "p-value:", p_alpha_mf)
print("MF Beta t-statistic:", t_beta_mf, "p-value:", p_beta_mf)

print("ETF Alpha t-statistic:", t_alpha_etf, "p-value:", p_alpha_etf)
print("ETF Beta t-statistic:", t_beta_etf, "p-value:", p_beta_etf)
# Out:
# MF Alpha t-statistic: 0.14124321405481613 p-value: 0.8877121225233211
# MF Beta t-statistic: -0.39336185793171435 p-value: 0.6941533772194515
# ETF Alpha t-statistic: 0.26694316812933466 p-value: 0.789579307814799
# ETF Beta t-statistic: 1.927908804606218 p-value: 0.05420776322115084

# %%
start_date_normal = pd.to_datetime("2016-01-05")
end_date_normal = pd.to_datetime("2019-12-31")
start_date_crisis = pd.to_datetime("2020-01-01")
end_date_crisis = pd.to_datetime("2023-04-28")

import pandas as pd

daily_returns_normal = daily_returns.loc[start_date_normal:end_date_normal]
daily_returns_crisis = daily_returns.loc[start_date_crisis:end_date_crisis]
sp500_returns_normal = sp500_returns.loc[start_date_normal:end_date_normal]
sp500_returns_crisis = sp500_returns.loc[start_date_crisis:end_date_crisis]

# Calculate average return for mutual funds
avg_mf_return_normal = daily_returns_normal[ticker_mf].mean().mean()
avg_mf_return_crisis = daily_returns_crisis[ticker_mf].mean().mean()
# Calculate average return for ETFs
avg_etf_return_normal = daily_returns_normal[ticker_etf].mean().mean()
avg_etf_return_crisis = daily_returns_crisis[ticker_etf].mean().mean()

avg_sp500_returns_normal = sp500_returns_normal.mean()
avg_sp500_returns_crisis = sp500_returns_crisis.mean()

print("Average Return for Mutual Funds normal:", avg_mf_return_normal)
print("Average Return for ETFs normal:", avg_etf_return_normal)
print("Average Return for SP500 normal:", avg_sp500_returns_normal)
print("Average Return for Mutual Funds crisis:", avg_mf_return_crisis)
print("Average Return for ETFs crisis:", avg_etf_return_crisis)
print("Average Return for SP500 crisis:", avg_sp500_returns_crisis)
# Out:
# Average Return for Mutual Funds normal: 0.00051246818600719
# Average Return for ETFs normal: 0.0005698585030069618
# Average Return for SP500 normal: 0.0005847745622568107
# Average Return for Mutual Funds crisis: 0.0004200101816281685
# Average Return for ETFs crisis: 0.0004862272355158169
# Average Return for SP500 crisis: 0.0004908689767005001

# %%
# Calculate average return for mutual funds
avg_mf_vol_normal = daily_returns_normal[ticker_mf].std().mean()
avg_mf_vol_crisis = daily_returns_crisis[ticker_mf].std().mean()
# Calculate average return for ETFs
avg_etf_vol_normal = daily_returns_normal[ticker_etf].std().mean()
avg_etf_vol_crisis = daily_returns_crisis[ticker_etf].std().mean()

print("Average Return for Mutual Funds normal:", avg_mf_vol_normal)
print("Average Return for ETFs normal:", avg_etf_vol_normal)
print("Average Return for Mutual Funds crisis:", avg_mf_vol_crisis)
print("Average Return for ETFs crisis:", avg_etf_vol_crisis)
# Out:
# Average Return for Mutual Funds normal: 0.008182082224894652
# Average Return for ETFs normal: 0.008115699613414558
# Average Return for Mutual Funds crisis: 0.015433889383985403
# Average Return for ETFs crisis: 0.01561342090401599

# %%
# Merge S&P 500 adjusted close prices into adj_close_stocks_filtered DataFrame
adj_close_stocks_filtered_andsp500 = adj_close_stocks_filtered.merge(sp500_adjclose, left_index=True, right_index=True)

adj_close_stocks_filtered_norm = adj_close_stocks_filtered_andsp500 / adj_close_stocks_filtered_andsp500.iloc[0]
adj_close_stocks_filtered_norm
# Out:
#                FRDAX     LMMRX     LMPIX     MRGAX     NSBFX     ITHIX  \
# Date
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2016-01-05  1.002126  1.003201  1.002029  1.003276  1.001851  1.000296
# 2016-01-06  0.988095  0.993063  0.990868  0.988534  0.987353  0.982524
# 2016-01-07  0.968324  0.973853  0.970066  0.967240  0.965762  0.955273
# 2016-01-08  0.956207  0.965848  0.959919  0.953727  0.955274  0.943128
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  2.419312  2.170532  2.191914  2.341406  2.251064  1.969029
# 2023-04-25  2.382994  2.145155  2.162993  2.304397  2.224105  1.935485
# 2023-04-26  2.371540  2.130881  2.152337  2.297457  2.209756  1.927658
# 2023-04-27  2.405902  2.166567  2.194958  2.338514  2.246281  1.957847
# 2023-04-28  2.424620  2.187979  2.211702  2.357597  2.268022  1.971824
#
#                FDETX     SCRLX     AFNAX     GATCX  ...       SPY       IVV  \
# Date                                                ...
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2016-01-05  0.999233  1.001565  1.006226  0.999201  ...  1.001692  1.002079
# 2016-01-06  0.979279  0.988782  0.995331  0.986611  ...  0.989056  0.988960
# 2016-01-07  0.950883  0.967389  0.973541  0.966027  ...  0.965327  0.965297
# 2016-01-08  0.940138  0.956170  0.962646  0.957234  ...  0.954731  0.954604
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-04-24  2.285076  2.527738  2.018698  1.807085  ...  2.337006  2.333181
# 2023-04-25  2.240128  2.498194  1.998756  1.786734  ...  2.299908  2.296134
# 2023-04-26  2.230410  2.498678  1.975188  1.771046  ...  2.290167  2.286789
# 2023-04-27  2.269284  2.555345  1.995130  1.799453  ...  2.335760  2.332167
# 2023-04-28  2.291151  2.575203  2.016885  1.809205  ...  2.355696  2.351479
#
#                  VIG      ITOT       RSP      SCHX      SPLG      GSLC  \
# Date
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2016-01-05  1.003258  1.001749  1.002375  1.002090  1.008238  1.002150
# 2016-01-06  0.991137  0.987538  0.984035  0.989133  0.993260  0.990469
# 2016-01-07  0.972889  0.963817  0.961736  0.965517  0.974751  0.970674
# 2016-01-08  0.962852  0.952448  0.949994  0.954650  0.965764  0.957967
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  2.355558  2.258408  2.170142  2.305544  2.371270  2.230189
# 2023-04-25  2.327031  2.219928  2.133223  2.267632  2.333639  2.195563
# 2023-04-26  2.307213  2.210246  2.110952  2.259101  2.324353  2.186294
# 2023-04-27  2.345048  2.251457  2.145629  2.302227  2.368826  2.227190
# 2023-04-28  2.365768  2.270821  2.169394  2.321657  2.389841  2.245184
#
#                 FTCS  Adj Close
# Date
# 2016-01-04  1.000000   1.000000
# 2016-01-05  1.006918   1.002014
# 2016-01-06  0.996008   0.989227
# 2016-01-07  0.974454   0.965808
# 2016-01-08  0.962746   0.955345
# ...              ...        ...
# 2023-04-24  2.154733   2.353168
# 2023-04-25  2.132270   2.316061
# 2023-04-26  2.102513   2.307177
# 2023-04-27  2.130519   2.352376
# 2023-04-28  2.145106   2.372044
#
# [1843 rows x 54 columns]

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot the ETFs
for column in ticker_etf:
    plt.plot(adj_close_stocks_filtered_norm.index, adj_close_stocks_filtered_norm[column], label=column)

# Plot the S&P 500
plt.plot(adj_close_stocks_filtered_norm.index, adj_close_stocks_filtered_norm['Adj Close'], label='S&P 500')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.title('Normalized ETF Prices with S&P 500')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot the ETFs
for column in ticker_mf:
    plt.plot(adj_close_stocks_filtered_norm.index, adj_close_stocks_filtered_norm[column], label=column)

# Plot the S&P 500
plt.plot(adj_close_stocks_filtered_norm.index, adj_close_stocks_filtered_norm['Adj Close'], label='S&P 500')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.title('Normalized MF Prices with S&P 500')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Calculate the average values for the mutual funds portfolio, ETFs portfolio, and S&P 500
portfolio_mf_avg_norm = adj_close_stocks_filtered_norm[ticker_mf].mean(axis=1)

portfolio_etf_avg_norm = adj_close_stocks_filtered_norm[ticker_etf].mean(axis=1)

sp500_avg_norm = adj_close_stocks_filtered_norm['Adj Close']

# Create a new DataFrame with the average values
df_portfolios_norm = pd.DataFrame({'Portfolio MF': portfolio_mf_avg_norm, 'Portfolio ETF': portfolio_etf_avg_norm, 'S&P 500': sp500_avg_norm})
df_portfolios_norm
# Out:
#             Portfolio MF  Portfolio ETF   S&P 500
# Date
# 2016-01-04      1.000000       1.000000  1.000000
# 2016-01-05      1.001447       1.003235  1.002014
# 2016-01-06      0.988178       0.988881  0.989227
# 2016-01-07      0.965445       0.966423  0.965808
# 2016-01-08      0.954434       0.955969  0.955345
# ...                  ...            ...       ...
# 2023-04-24      2.080093       2.311910  2.353168
# 2023-04-25      2.048502       2.274751  2.316061
# 2023-04-26      2.035952       2.262566  2.307177
# 2023-04-27      2.072306       2.305720  2.352376
# 2023-04-28      2.090319       2.326539  2.372044
#
# [1843 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot the lines
plt.plot(df_portfolios_norm.index, df_portfolios_norm['Portfolio MF'], label='Portfolio MF')
plt.plot(df_portfolios_norm.index, df_portfolios_norm['Portfolio ETF'], label='Portfolio ETF')
plt.plot(df_portfolios_norm.index, df_portfolios_norm['S&P 500'], label='S&P 500')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.title('Performance Comparison')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
adj_close_stocks_filtered_andsp500
# Out:
#                 FRDAX      LMMRX      LMPIX      MRGAX      NSBFX      ITHIX  \
# Date
# 2016-01-04  35.795307  12.609810  13.139204  17.293030  22.998016  17.886993
# 2016-01-05  35.871395  12.650180  13.165870  17.349682  23.040577  17.892292
# 2016-01-06  35.369164  12.522333  13.019214  17.094749  22.707170  17.574398
# 2016-01-07  34.661472  12.280096  12.745895  16.726511  22.210608  17.086954
# 2016-01-08  34.227737  12.179164  12.612569  16.492823  21.969418  16.869724
# ...               ...        ...        ...        ...        ...        ...
# 2023-04-24  86.599998  27.370001  28.799999  40.490002  51.770000  35.220001
# 2023-04-25  85.300003  27.049999  28.420000  39.849998  51.150002  34.619999
# 2023-04-26  84.889999  26.870001  28.280001  39.730000  50.820000  34.480000
# 2023-04-27  86.120003  27.320000  28.840000  40.439999  51.660000  35.020000
# 2023-04-28  86.790001  27.590000  29.059999  40.770000  52.160000  35.270000
#
#                 FDETX      SCRLX      AFNAX      GATCX  ...         SPY  \
# Date                                                    ...
# 2016-01-04   8.231672  20.646919  11.031862  23.584938  ...  175.910110
# 2016-01-05   8.225356  20.679239  11.100542  23.566084  ...  176.207672
# 2016-01-06   8.061100  20.415297  10.980350  23.269148  ...  173.984879
# 2016-01-07   7.827354  19.973593  10.739968  22.783691  ...  169.810745
# 2016-01-08   7.738909  19.741968  10.619775  22.576309  ...  167.946808
# ...               ...        ...        ...        ...  ...         ...
# 2023-04-24  18.809999  52.189999  22.270000  42.619999  ...  411.102936
# 2023-04-25  18.440001  51.580002  22.049999  42.139999  ...  404.577148
# 2023-04-26  18.360001  51.590000  21.790001  41.770000  ...  402.863495
# 2023-04-27  18.680000  52.759998  22.010000  42.439999  ...  410.883728
# 2023-04-28  18.860001  53.169998  22.250000  42.669998  ...  414.390686
#
#                    IVV         VIG       ITOT         RSP       SCHX  \
# Date
# 2016-01-04  177.062759   66.604179  40.160004   66.903465  21.101311
# 2016-01-05  177.430908   66.821198  40.230228   67.062370  21.145409
# 2016-01-06  175.108032   66.013840  39.659534   65.835342  20.871994
# 2016-01-07  170.918167   64.798447  38.706894   64.343498  20.373676
# 2016-01-08  169.024780   64.129967  38.250328   63.557869  20.144361
# ...                ...         ...        ...         ...        ...
# 2023-04-24  413.119446  156.889999  90.697685  145.190002  48.650002
# 2023-04-25  406.559906  154.990005  89.152321  142.720001  47.849998
# 2023-04-26  404.905121  153.669998  88.763489  141.229996  47.669998
# 2023-04-27  412.940002  156.190002  90.418526  143.550003  48.580002
# 2023-04-28  416.359314  157.570007  91.196190  145.139999  48.990002
#
#                  SPLG       GSLC       FTCS    Adj Close
# Date
# 2016-01-04  20.461609  36.678513  34.278027  3763.989990
# 2016-01-05  20.630169  36.757385  34.515179  3771.570068
# 2016-01-06  20.323692  36.328922  34.141205  3723.439941
# 2016-01-07  19.944981  35.602886  33.402363  3635.290039
# 2016-01-08  19.761093  35.136787  33.001034  3595.909912
# ...               ...        ...        ...          ...
# 2023-04-24  48.520000  81.800003  73.860001  8857.299805
# 2023-04-25  47.750000  80.529999  73.089996  8717.629883
# 2023-04-26  47.560001  80.190002  72.070000  8684.190430
# 2023-04-27  48.470001  81.690002  73.029999  8854.320312
# 2023-04-28  48.900002  82.349998  73.529999  8928.349609
#
# [1843 rows x 54 columns]

# %%
startdatecov = pd.Timestamp('2019-08-30')
enddatecov = pd.Timestamp('2023-05-01')

# Slice the DataFrame using the specified start and end dates
adj_close_stocks_filtered_crisis = adj_close_stocks_filtered_andsp500.loc[startdatecov:enddatecov]

# Normalize the sliced DataFrame
adj_close_stocks_filtered_norm_crisis = adj_close_stocks_filtered_crisis / adj_close_stocks_filtered_crisis.iloc[0]
adj_close_stocks_filtered_norm_crisis
# Out:
#                FRDAX     LMMRX     LMPIX     MRGAX     NSBFX     ITHIX  \
# Date
# 2019-08-30  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-09-03  0.989819  0.995550  0.993822  0.994145  0.995542  0.994880
# 2019-09-04  1.002395  1.006473  1.005019  1.004314  1.005350  1.002425
# 2019-09-05  1.014523  1.015372  1.016602  1.016333  1.012260  1.011318
# 2019-09-06  1.017667  1.017395  1.018147  1.017257  1.014935  1.011857
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  1.493309  1.377431  1.433331  1.439760  1.417919  1.303874
# 2023-04-25  1.470892  1.361326  1.414419  1.417003  1.400938  1.281662
# 2023-04-26  1.463822  1.352268  1.407451  1.412736  1.391900  1.276479
# 2023-04-27  1.485032  1.374914  1.435322  1.437982  1.414906  1.296470
# 2023-04-28  1.496586  1.388502  1.446271  1.449716  1.428601  1.305725
#
#                FDETX     SCRLX     AFNAX     GATCX  ...       SPY       IVV  \
# Date                                                ...
# 2019-08-30  1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2019-09-03  0.992662  0.991500  0.997332  0.992005  ...  0.994153  0.993679
# 2019-09-04  1.008005  1.002297  1.005870  1.004597  ...  1.005437  1.005063
# 2019-09-05  1.022014  1.016540  1.012274  1.018389  ...  1.018362  1.018215
# 2019-09-06  1.020680  1.017000  1.014942  1.020987  ...  1.019149  1.018894
# ...              ...       ...       ...       ...  ...       ...       ...
# 2023-04-24  1.575722  1.558144  1.302166  1.318604  ...  1.499927  1.501262
# 2023-04-25  1.544728  1.539932  1.289302  1.303754  ...  1.476117  1.477424
# 2023-04-26  1.538026  1.540230  1.274100  1.292306  ...  1.469865  1.471411
# 2023-04-27  1.564832  1.575161  1.286964  1.313035  ...  1.499127  1.500610
# 2023-04-28  1.579911  1.587402  1.300997  1.320151  ...  1.511922  1.513035
#
#                  VIG      ITOT       RSP      SCHX      SPLG      GSLC  \
# Date
# 2019-08-30  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2019-09-03  0.994680  0.993052  0.994389  0.993853  0.993895  0.994752
# 2019-09-04  1.006418  1.004380  1.006181  1.004861  1.004651  1.004571
# 2019-09-05  1.016382  1.018125  1.020920  1.018013  1.017732  1.018622
# 2019-09-06  1.018071  1.017973  1.023393  1.018728  1.018314  1.019807
# ...              ...       ...       ...       ...       ...       ...
# 2023-04-24  1.422039  1.460675  1.477811  1.482564  1.502853  1.458871
# 2023-04-25  1.404817  1.435787  1.452670  1.458185  1.479003  1.436221
# 2023-04-26  1.392853  1.429525  1.437504  1.452699  1.473118  1.430158
# 2023-04-27  1.415694  1.456179  1.461118  1.480431  1.501304  1.456909
# 2023-04-28  1.428202  1.468703  1.477302  1.492925  1.514623  1.468680
#
#                 FTCS  Adj Close
# Date
# 2019-08-30  1.000000   1.000000
# 2019-09-03  0.993836   0.993171
# 2019-09-04  1.002290   1.004023
# 2019-09-05  1.015146   1.017319
# 2019-09-06  1.017612   1.018283
# ...              ...        ...
# 2023-04-24  1.363380   1.501688
# 2023-04-25  1.349167   1.478008
# 2023-04-26  1.330339   1.472338
# 2023-04-27  1.348059   1.501183
# 2023-04-28  1.357289   1.513734
#
# [922 rows x 54 columns]

# %%
startdatenormal = pd.Timestamp('2016-01-01')
enddatenormal = pd.Timestamp('2019-08-31')

# Slice the DataFrame using the specified start and end dates
adj_close_stocks_filtered_normal = adj_close_stocks_filtered_andsp500.loc[startdatenormal:enddatenormal]

# Normalize the sliced DataFrame
adj_close_stocks_filtered_norm_normal = adj_close_stocks_filtered_normal / adj_close_stocks_filtered_normal.iloc[0]
adj_close_stocks_filtered_norm_normal
# Out:
#                FRDAX     LMMRX     LMPIX     MRGAX     NSBFX     ITHIX  \
# Date
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2016-01-05  1.002126  1.003201  1.002029  1.003276  1.001851  1.000296
# 2016-01-06  0.988095  0.993063  0.990868  0.988534  0.987353  0.982524
# 2016-01-07  0.968324  0.973853  0.970066  0.967240  0.965762  0.955273
# 2016-01-08  0.956207  0.965848  0.959919  0.953727  0.955274  0.943128
# ...              ...       ...       ...       ...       ...       ...
# 2019-08-26  1.585414  1.550285  1.503265  1.599686  1.563164  1.488569
# 2019-08-27  1.587597  1.547736  1.500904  1.594173  1.558917  1.484093
# 2019-08-28  1.598027  1.557935  1.509760  1.603194  1.568826  1.491825
# 2019-08-29  1.617190  1.573871  1.528064  1.624744  1.585813  1.509730
# 2019-08-30  1.620101  1.575783  1.529245  1.626247  1.587583  1.510137
#
#                FDETX     SCRLX     AFNAX     GATCX  ...       SPY       IVV  \
# Date                                                ...
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  ...  1.000000  1.000000
# 2016-01-05  0.999233  1.001565  1.006226  0.999201  ...  1.001692  1.002079
# 2016-01-06  0.979279  0.988782  0.995331  0.986611  ...  0.989056  0.988960
# 2016-01-07  0.950883  0.967389  0.973541  0.966027  ...  0.965327  0.965297
# 2016-01-08  0.940138  0.956170  0.962646  0.957234  ...  0.954731  0.954604
# ...              ...       ...       ...       ...  ...       ...       ...
# 2019-08-26  1.428893  1.598051  1.524719  1.341965  ...  1.534372  1.529800
# 2019-08-27  1.418252  1.592834  1.523894  1.339500  ...  1.528352  1.523937
# 2019-08-28  1.428893  1.602523  1.533799  1.348265  ...  1.539114  1.534236
# 2019-08-29  1.447274  1.622648  1.548607  1.366618  ...  1.558773  1.554200
# 2019-08-30  1.450177  1.622275  1.550262  1.370453  ...  1.558080  1.554147
#
#                  VIG      ITOT       RSP      SCHX      SPLG      GSLC  \
# Date
# 2016-01-04  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 2016-01-05  1.003258  1.001749  1.002375  1.002090  1.008238  1.002150
# 2016-01-06  0.991137  0.987538  0.984035  0.989133  0.993260  0.990469
# 2016-01-07  0.972889  0.963817  0.961736  0.965517  0.974751  0.970674
# 2016-01-08  0.962852  0.952448  0.949994  0.954650  0.965764  0.957967
# ...              ...       ...       ...       ...       ...       ...
# 2019-08-26  1.626810  1.522789  1.444047  1.531318  1.553995  1.504382
# 2019-08-27  1.629049  1.516484  1.435947  1.525093  1.546656  1.499464
# 2019-08-28  1.638281  1.526992  1.448376  1.534653  1.557664  1.509299
# 2019-08-29  1.657165  1.546374  1.467926  1.554661  1.576929  1.529226
# 2019-08-30  1.656465  1.546141  1.468484  1.555106  1.577846  1.528708
#
#                 FTCS  Adj Close
# Date
# 2016-01-04  1.000000   1.000000
# 2016-01-05  1.006918   1.002014
# 2016-01-06  0.996008   0.989227
# 2016-01-07  0.974454   0.965808
# 2016-01-08  0.962746   0.955345
# ...              ...        ...
# 2019-08-26  1.551209   1.540743
# 2019-08-27  1.552043   1.535814
# 2019-08-28  1.562899   1.545923
# 2019-08-29  1.580434   1.565799
# 2019-08-30  1.580434   1.567015
#
# [922 rows x 54 columns]

# %%
portfolio_mf_avg_norm_crisis = adj_close_stocks_filtered_norm_crisis[ticker_mf].mean(axis=1)

portfolio_etf_avg_norm_crisis = adj_close_stocks_filtered_norm_crisis[ticker_etf].mean(axis=1)

sp500_avg_norm_crisis = adj_close_stocks_filtered_norm_crisis['Adj Close']

# Create a new DataFrame with the average values
df_portfolios_norm_crisis = pd.DataFrame({'Portfolio MF': portfolio_mf_avg_norm_crisis, 'Portfolio ETF': portfolio_etf_avg_norm_crisis, 'S&P 500': sp500_avg_norm_crisis})
df_portfolios_norm_crisis
# Out:
#             Portfolio MF  Portfolio ETF   S&P 500
# Date
# 2019-08-30      1.000000       1.000000  1.000000
# 2019-09-03      0.992496       0.994114  0.993171
# 2019-09-04      1.003252       1.005287  1.004023
# 2019-09-05      1.015848       1.018724  1.017319
# 2019-09-06      1.016825       1.019777  1.018283
# ...                  ...            ...       ...
# 2023-04-24      1.406181       1.496802  1.501688
# 2023-04-25      1.384770       1.472727  1.478008
# 2023-04-26      1.376267       1.464749  1.472338
# 2023-04-27      1.400876       1.492641  1.501183
# 2023-04-28      1.413065       1.506154  1.513734
#
# [922 rows x 3 columns]

# %%
portfolio_mf_avg_norm_normal = adj_close_stocks_filtered_norm_normal[ticker_mf].mean(axis=1)

portfolio_etf_avg_norm_normal = adj_close_stocks_filtered_norm_normal[ticker_etf].mean(axis=1)

sp500_avg_norm_normal = adj_close_stocks_filtered_norm_normal['Adj Close']

# Create a new DataFrame with the average values
df_portfolios_norm_normal = pd.DataFrame({'Portfolio MF': portfolio_mf_avg_norm_normal, 'Portfolio ETF': portfolio_etf_avg_norm_normal, 'S&P 500': sp500_avg_norm_normal})
df_portfolios_norm_normal
# Out:
#             Portfolio MF  Portfolio ETF   S&P 500
# Date
# 2016-01-04      1.000000       1.000000  1.000000
# 2016-01-05      1.001447       1.003235  1.002014
# 2016-01-06      0.988178       0.988881  0.989227
# 2016-01-07      0.965445       0.966423  0.965808
# 2016-01-08      0.954434       0.955969  0.955345
# ...                  ...            ...       ...
# 2019-08-26      1.451966       1.520246  1.540743
# 2019-08-27      1.447120       1.513572  1.535814
# 2019-08-28      1.456850       1.524601  1.545923
# 2019-08-29      1.475283       1.544304  1.565799
# 2019-08-30      1.476705       1.544322  1.567015
#
# [922 rows x 3 columns]

# %%
# Calculate the difference 
df_portfolios_norm_normal['Difference MF-ETF'] = df_portfolios_norm_normal['Portfolio MF'] - df_portfolios_norm_normal['Portfolio ETF']
df_portfolios_norm_normal['Difference MF-SP500'] = df_portfolios_norm_normal['Portfolio MF'] - df_portfolios_norm_normal['S&P 500']
df_portfolios_norm_normal['Difference ETF-SP500'] = df_portfolios_norm_normal['Portfolio ETF'] - df_portfolios_norm_normal['S&P 500']

# Calculate the average differences
average_difference_mf_etf_normal = df_portfolios_norm_normal['Difference MF-ETF'].mean()
average_difference_mf_sp500_normal = df_portfolios_norm_normal['Difference MF-SP500'].mean()
average_difference_etf_sp500_normal = df_portfolios_norm_normal['Difference ETF-SP500'].mean()

print("Average difference between MF and ETF:", average_difference_mf_etf_normal)
print("Average difference between MF and S&P 500:", average_difference_mf_sp500_normal)
print("Average difference between ETF and S&P 500:", average_difference_etf_sp500_normal)
# Out:
# Average difference between MF and ETF: -0.03733765452545866
# Average difference between MF and S&P 500: -0.042147641935455955
# Average difference between ETF and S&P 500: -0.004809987409997297

# %%
# Calculate the difference 
df_portfolios_norm_crisis['Difference MF-ETF'] = df_portfolios_norm_crisis['Portfolio MF'] - df_portfolios_norm_crisis['Portfolio ETF']
df_portfolios_norm_crisis['Difference MF-SP500'] = df_portfolios_norm_crisis['Portfolio MF'] - df_portfolios_norm_crisis['S&P 500']
df_portfolios_norm_crisis['Difference ETF-SP500'] = df_portfolios_norm_crisis['Portfolio ETF'] - df_portfolios_norm_crisis['S&P 500']

# Calculate the average differences
average_difference_mf_etf = df_portfolios_norm_crisis['Difference MF-ETF'].mean()
average_difference_mf_sp500 = df_portfolios_norm_crisis['Difference MF-SP500'].mean()
average_difference_etf_sp500 = df_portfolios_norm_crisis['Difference ETF-SP500'].mean()

print("Average difference between MF and ETF:", average_difference_mf_etf)
print("Average difference between MF and S&P 500:", average_difference_mf_sp500)
print("Average difference between ETF and S&P 500:", average_difference_etf_sp500)
# Out:
# Average difference between MF and ETF: -0.05423886143424791
# Average difference between MF and S&P 500: -0.06004560373963862
# Average difference between ETF and S&P 500: -0.005806742305390705

# %%
df_portfolios_norm_crisis
# Out:
#             Portfolio MF  Portfolio ETF   S&P 500  Difference MF-ETF  \
# Date
# 2019-08-30      1.000000       1.000000  1.000000           0.000000
# 2019-09-03      0.992496       0.994114  0.993171          -0.001618
# 2019-09-04      1.003252       1.005287  1.004023          -0.002035
# 2019-09-05      1.015848       1.018724  1.017319          -0.002876
# 2019-09-06      1.016825       1.019777  1.018283          -0.002952
# ...                  ...            ...       ...                ...
# 2023-04-24      1.406181       1.496802  1.501688          -0.090621
# 2023-04-25      1.384770       1.472727  1.478008          -0.087957
# 2023-04-26      1.376267       1.464749  1.472338          -0.088482
# 2023-04-27      1.400876       1.492641  1.501183          -0.091765
# 2023-04-28      1.413065       1.506154  1.513734          -0.093089
#
#             Difference MF-SP500  Difference ETF-SP500
# Date
# 2019-08-30             0.000000              0.000000
# 2019-09-03            -0.000675              0.000943
# 2019-09-04            -0.000771              0.001263
# 2019-09-05            -0.001470              0.001406
# 2019-09-06            -0.001459              0.001494
# ...                         ...                   ...
# 2023-04-24            -0.095507             -0.004886
# 2023-04-25            -0.093238             -0.005280
# 2023-04-26            -0.096072             -0.007590
# 2023-04-27            -0.100306             -0.008541
# 2023-04-28            -0.100669             -0.007580
#
# [922 rows x 6 columns]

# %%
from scipy.stats import ttest_ind

# Extract the difference values during normal times and crisis times
normal_diff_mf_etf = df_portfolios_norm_normal['Difference MF-ETF']
crisis_diff_mf_etf = df_portfolios_norm_crisis['Difference MF-ETF']

# Perform t-test
t_stat, p_value = ttest_ind(normal_diff_mf_etf, crisis_diff_mf_etf)

# Check if the difference is statistically significant
alpha = 0.05  # significance level
if p_value < alpha:
    print("There is a significant difference between MF and ETF during normal times and crisis times.")
else:
    print("There is no significant difference between MF and ETF during normal times and crisis times.")
print("p-value:", p_value)
# Out:
# There is a significant difference between MF and ETF during normal times and crisis times.
# p-value: 8.012157143285063e-43

# %%
startdate2021 = pd.Timestamp('2021-01-01')
enddate2021 = pd.Timestamp('2021-12-31')

# Slice the DataFrame using the specified start and end dates
adj_close_stocks_filtered_2021 = adj_close_stocks_filtered_andsp500.loc[startdate2021:enddate2021]

# Normalize the sliced DataFrame
adj_close_stocks_filtered_norm_2021 = adj_close_stocks_filtered_2021 / adj_close_stocks_filtered_2021.iloc[0]

# %%
portfolio_mf_avg_norm_2021 = adj_close_stocks_filtered_norm_2021[ticker_mf].mean(axis=1)

portfolio_etf_avg_norm_2021 = adj_close_stocks_filtered_norm_2021[ticker_etf].mean(axis=1)

sp500_avg_norm_2021 = adj_close_stocks_filtered_norm_2021['Adj Close']

# Create a new DataFrame with the average values
df_portfolios_norm_2021 = pd.DataFrame({'Portfolio MF': portfolio_mf_avg_norm_2021, 'Portfolio ETF': portfolio_etf_avg_norm_2021, 'S&P 500': sp500_avg_norm_2021})
df_portfolios_norm_2021
# Out:
#             Portfolio MF  Portfolio ETF   S&P 500
# Date
# 2021-01-04      1.000000       1.000000  1.000000
# 2021-01-05      1.007727       1.007103  1.007203
# 2021-01-06      1.019074       1.016671  1.012970
# 2021-01-07      1.032907       1.030756  1.028231
# 2021-01-08      1.036405       1.035914  1.034009
# ...                  ...            ...       ...
# 2021-12-27      1.282066       1.311547  1.312925
# 2021-12-28      1.281582       1.311056  1.311599
# 2021-12-29      1.283942       1.313177  1.313441
# 2021-12-30      1.280692       1.309803  1.309635
# 2021-12-31      1.278987       1.306980  1.306259
#
# [252 rows x 3 columns]

# %%
# Calculate the difference 
df_portfolios_norm_2021['Difference MF-ETF'] = df_portfolios_norm_2021['Portfolio MF'] - df_portfolios_norm_2021['Portfolio ETF']
df_portfolios_norm_2021['Difference MF-SP500'] = df_portfolios_norm_2021['Portfolio MF'] - df_portfolios_norm_2021['S&P 500']
df_portfolios_norm_2021['Difference ETF-SP500'] = df_portfolios_norm_2021['Portfolio ETF'] - df_portfolios_norm_2021['S&P 500']

# Calculate the average differences
average_difference_mf_etf_2021 = df_portfolios_norm_2021['Difference MF-ETF'].mean()
average_difference_mf_sp500_2021 = df_portfolios_norm_2021['Difference MF-SP500'].mean()
average_difference_etf_sp500_2021 = df_portfolios_norm_2021['Difference ETF-SP500'].mean()

print("Average difference between MF and ETF:", average_difference_mf_etf_2021)
print("Average difference between MF and S&P 500:", average_difference_mf_sp500_2021)
print("Average difference between ETF and S&P 500:", average_difference_etf_sp500_2021)
# Out:
# Average difference between MF and ETF: -0.011909407009919137
# Average difference between MF and S&P 500: -0.0066185402528688335
# Average difference between ETF and S&P 500: 0.0052908667570503035

# %%
startdate2022 = pd.Timestamp('2022-01-01')
enddate2022 = pd.Timestamp('2023-01-03')

# Slice the DataFrame using the specified start and end dates
adj_close_stocks_filtered_2022 = adj_close_stocks_filtered_andsp500.loc[startdate2022:enddate2022]

# Normalize the sliced DataFrame
adj_close_stocks_filtered_norm_2022 = adj_close_stocks_filtered_2022 / adj_close_stocks_filtered_2022.iloc[0]

# %%
portfolio_mf_avg_norm_2022 = adj_close_stocks_filtered_norm_2022[ticker_mf].mean(axis=1)
portfolio_etf_avg_norm_2022 = adj_close_stocks_filtered_norm_2022[ticker_etf].mean(axis=1)
sp500_avg_norm_2022 = adj_close_stocks_filtered_norm_2022['Adj Close']

# Create a new DataFrame with the average values
df_portfolios_norm_2022 = pd.DataFrame({'Portfolio MF': portfolio_mf_avg_norm_2022, 'Portfolio ETF': portfolio_etf_avg_norm_2022, 'S&P 500': sp500_avg_norm_2022})
df_portfolios_norm_2022
# Out:
#             Portfolio MF  Portfolio ETF   S&P 500
# Date
# 2022-01-03      1.000000       1.000000  1.000000
# 2022-01-04      1.002442       1.001322  0.999437
# 2022-01-05      0.984415       0.982770  0.980129
# 2022-01-06      0.983996       0.982440  0.979256
# 2022-01-07      0.979960       0.979137  0.975468
# ...                  ...            ...       ...
# 2022-12-27      0.834560       0.825795  0.811367
# 2022-12-28      0.824587       0.815327  0.801621
# 2022-12-29      0.837663       0.829751  0.815724
# 2022-12-30      0.835102       0.827446  0.813700
# 2023-01-03      0.832933       0.824539  0.810474
#
# [252 rows x 3 columns]

# %%
# Calculate the difference 
df_portfolios_norm_2022['Difference MF-ETF'] = df_portfolios_norm_2022['Portfolio MF'] - df_portfolios_norm_2022['Portfolio ETF']
df_portfolios_norm_2022['Difference MF-SP500'] = df_portfolios_norm_2022['Portfolio MF'] - df_portfolios_norm_2022['S&P 500']
df_portfolios_norm_2022['Difference ETF-SP500'] = df_portfolios_norm_2022['Portfolio ETF'] - df_portfolios_norm_2022['S&P 500']

# Calculate the average differences
average_difference_mf_etf_2022 = df_portfolios_norm_2022['Difference MF-ETF'].mean()
average_difference_mf_sp500_2022 = df_portfolios_norm_2022['Difference MF-SP500'].mean()
average_difference_etf_sp500_2022 = df_portfolios_norm_2022['Difference ETF-SP500'].mean()

print("Average difference between MF and ETF:", average_difference_mf_etf_2022)
print("Average difference between MF and S&P 500:", average_difference_mf_sp500_2022)
print("Average difference between ETF and S&P 500:", average_difference_etf_sp500_2022)
# Out:
# Average difference between MF and ETF: 0.00020039675186001775
# Average difference between MF and S&P 500: 0.00828817328983598
# Average difference between ETF and S&P 500: 0.008087776537975962

# %%
from scipy.stats import ttest_ind

# Extract the difference values during normal times and crisis times
_2021_diff_mf_etf = df_portfolios_norm_2021['Difference MF-ETF']
_2022_diff_mf_etf = df_portfolios_norm_2022['Difference MF-ETF']

# Perform t-test
t_stat, p_value = ttest_ind(_2021_diff_mf_etf, _2022_diff_mf_etf)

# Check if the difference is statistically significant
alpha = 0.05  # significance level
if p_value < alpha:
    print("There is a significant difference between MF and ETF during normal times and crisis times.")
else:
    print("There is no significant difference between MF and ETF during normal times and crisis times.")
print("p-value:", p_value)
# Out:
# There is a significant difference between MF and ETF during normal times and crisis times.
# p-value: 8.943291411530414e-60

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_covid = df_portfolios_norm_2021.loc[pd.to_datetime(startdate2021):pd.to_datetime(enddate2021)]

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot the lines
plt.plot(df_covid.index, df_covid['Portfolio MF'], label='Portfolio MF')
plt.plot(df_covid.index, df_covid['Portfolio ETF'], label='Portfolio ETF')
plt.plot(df_covid.index, df_covid['S&P 500'], label='S&P 500')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.title('Performance Comparison')

# Add a legend
plt.legend()

# Add start and end dates as text annotations
plt.text(df_covid.index[0], df_covid[['Portfolio MF', 'Portfolio ETF', 'S&P 500']].max())
plt.text(df_covid.index[-1], df_covid[['Portfolio MF', 'Portfolio ETF', 'S&P 500']].max())

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 23
#      20 plt.legend()
#      22 # Add start and end dates as text annotations
# ---> 23 plt.text(df_covid.index[0], df_covid[['Portfolio MF', 'Portfolio ETF', 'S&P 500']].max())
#      24 plt.text(df_covid.index[-1], df_covid[['Portfolio MF', 'Portfolio ETF', 'S&P 500']].max())
#      26 # Show the plot
#
# TypeError: text() missing 1 required positional argument: 's'

# %%
startdate20 = pd.Timestamp('2022-01-01')
enddate2022 = pd.Timestamp('2023-01-03')

# Slice the DataFrame using the specified start and end dates
adj_close_stocks_filtered_2022 = adj_close_stocks_filtered_andsp500.loc[startdate2022:enddate2022]

# Normalize the sliced DataFrame
adj_close_stocks_filtered_norm_2022 = adj_close_stocks_filtered_2022 / adj_close_stocks_filtered_2022.iloc[0]

# %%
portfolio_mf_avg_norm_2022 = adj_close_stocks_filtered_norm_2022[ticker_mf].mean(axis=1)
portfolio_etf_avg_norm_2022 = adj_close_stocks_filtered_norm_2022[ticker_etf].mean(axis=1)
sp500_avg_norm_2022 = adj_close_stocks_filtered_norm_2022['Adj Close']

# Create a new DataFrame with the average values
df_portfolios_norm_2022 = pd.DataFrame({'Portfolio MF': portfolio_mf_avg_norm_2022, 'Portfolio ETF': portfolio_etf_avg_norm_2022, 'S&P 500': sp500_avg_norm_2022})
df_portfolios_norm_2022

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_covid = df_portfolios_norm_2021.loc[pd.to_datetime(startdate2021):pd.to_datetime(enddate2021)]

# Set the figure size
plt.figure(figsize=(12, 6))

# Plot the lines
plt.plot(df_covid.index, df_covid['Portfolio MF'], label='Portfolio MF')
plt.plot(df_covid.index, df_covid['Portfolio ETF'], label='Portfolio ETF')
plt.plot(df_covid.index, df_covid['S&P 500'], label='S&P 500')

# Add labels and title
plt.xlabel('Date')
plt.ylabel('Normalized Value')
plt.title('Performance Comparison')

# Add a legend
plt.legend()

# Add start and end dates as text annotations
plt.text(df_covid.index[0], df_covid[['Portfolio MF', 'Portfolio ETF', 'S&P 500']].max())
plt.text(df_covid.index[-1], df_covid[['Portfolio MF', 'Portfolio ETF', 'S&P 500']].max())

# Show the plot
plt.show()
